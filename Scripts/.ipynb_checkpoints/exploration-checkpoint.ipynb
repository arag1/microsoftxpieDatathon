# %%
from text_analytics import *
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# Bad key "text.kerning_factor" on line 4 in
# C:\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test_patch.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution

# %%
data = pd.read_csv('../Data/support_ticket_data.csv', encoding='Windows-1252')
data.head()
# Out:
#    SupportTicketID  CustomerID DateCreated DateCompleted  Escalated     Theme  \
# 0            16582    10007217  30/06/2018      4/7/2018          1     price
# 1            13830    10005984  15/07/2018    18/07/2018          0     speed
# 2            53794    10022738  14/10/2018    18/10/2018          0  features
# 3            95013    10040142   1/11/2018    10/11/2018          0     price
# 4            32660    10013924    6/6/2018      6/6/2018          1    design
#
#                                           Theme_Desc  \
# 0  cost of the goods to customers.  compare to co...
# 1                       consider the delivery speed.
# 2  product features, website features, checkout f...
# 3  cost of the goods to customers.  compare to co...
# 4                     product design, website design
#
#                                                 Text
# 0  A screwdriver costs over a hundred dollars? Wh...
# 1    Anyway that I can rush overnight ship my order?
# 2  Are the shelves removable from the wine fridge...
# 3           Are there any Christmas sales coming up?
# 4  Are there any other colors in the bathroom sin...

# %%
len(data)
# Out:
# 328

# %% [markdown]
# ## Questions to investigate:
# 1) How long does it take for a support ticket to be resolved?
#       - Grouping by category and looking at response time.
# 2) Potential fraudulent/spam support tickets
#       - Look at time, security, services
#       - Look at text column maybe classification
#           - Most common words that occur
#       - Why is 35% of the data having a negative process time
# 3) What factors influence a ticket to be escalated?
#      - Text (topics), theme, date created
# 4) Classifier which predicts the theme based on the text

# %%
data.groupby('Theme').count()[['SupportTicketID']].sort_values('SupportTicketID', ascending = False)
# Out:
#              SupportTicketID
# Theme
# speed                     77
# price                     59
# features                  49
# services                  34
# reliability               31
# security                  26
# support                   21
# design                    18
# other                     13

# %%
data.groupby('Escalated').count()[['SupportTicketID']].sort_values('SupportTicketID', ascending = False)
# Out:
#            SupportTicketID
# Escalated
# 0                      288
# 1                       40

# %%
data['DateCompleted'] = pd.to_datetime(data['DateCompleted'])
data['DateCreated'] = pd.to_datetime(data['DateCreated'])
data['Process Time'] = (data['DateCompleted'] - data['DateCreated']).dt.days
data
# Out:
#      SupportTicketID  CustomerID DateCreated DateCompleted  Escalated  \
# 0              16582    10007217  2018-06-30    2018-04-07          1
# 1              13830    10005984  2018-07-15    2018-07-18          0
# 2              53794    10022738  2018-10-14    2018-10-18          0
# 3              95013    10040142  2018-01-11    2018-10-11          0
# 4              32660    10013924  2018-06-06    2018-06-06          1
# ..               ...         ...         ...           ...        ...
# 323           123579    10044731  2018-09-21    2018-09-30          0
# 324           101069    10041114  2018-01-12    2018-06-12          0
# 325            73065    10030954  2018-03-06    2018-05-06          0
# 326            52174    10022074  2018-03-06    2018-03-06          1
# 327            29179    10012482  2018-07-14    2018-07-14          0
#
#            Theme                                         Theme_Desc  \
# 0          price  cost of the goods to customers.  compare to co...
# 1          speed                       consider the delivery speed.
# 2       features  product features, website features, checkout f...
# 3          price  cost of the goods to customers.  compare to co...
# 4         design                     product design, website design
# ..           ...                                                ...
# 323  reliability  product reliability, website reliability, deli...
# 324  reliability  product reliability, website reliability, deli...
# 325  reliability  product reliability, website reliability, deli...
# 326     features  product features, website features, checkout f...
# 327        speed                       consider the delivery speed.
#
#                                                   Text  Process Time
# 0    A screwdriver costs over a hundred dollars? Wh...           -84
# 1      Anyway that I can rush overnight ship my order?             3
# 2    Are the shelves removable from the wine fridge...             4
# 3             Are there any Christmas sales coming up?           273
# 4    Are there any other colors in the bathroom sin...             0
# ..                                                 ...           ...
# 323  Your website is super glitchy. It won't let me...             9
# 324  Your website keeps crashing and forgetting eve...           151
# 325   Your website keeps crashing on mobile. It sucks.            61
# 326  Your website's check out system bugs when I us...             0
# 327                                                NaN             0
#
# [328 rows x 9 columns]

# %%
len(susProcessTime) / len(data)
# Out:
# 0.1676829268292683

# %%
susProcessTime = data[data['Process Time'] < 0]
normalProcessTime = data[data['Process Time'] >= 0]

# %%
susInter = susProcessTime.groupby('Theme').count()['SupportTicketID'] 
susThemeCounts = susInter / sum(susInter)
plt.figure(figsize = (10, 5))
susThemeCounts.plot(kind = 'bar');

# %%
normalInter = normalProcessTime.groupby('Theme').count()['SupportTicketID'] 
normalThemeCounts = normalInter / sum(normalInter)
plt.figure(figsize = (10, 5))
normalThemeCounts.plot(kind = 'bar');

# %%
susProcessTime[susProcessTime['Theme'] == 'services']
# Out:
#      SupportTicketID  CustomerID DateCreated DateCompleted  Escalated  \
# 245            84721    10036036  2018-05-31    2018-02-06          0
#
#         Theme                                         Theme_Desc  \
# 245  services  delivery services, installation services, acco...
#
#                                                   Text  Process Time
# 245  The installation team was prompt and polite.  ...          -114

# %%
dataInter = data.groupby('Theme').count()['SupportTicketID'] 
dataThemeCounts = dataInter / sum(dataInter)
plt.figure(figsize = (10, 5))
dataThemeCounts.plot(kind = 'bar');

# %%
for i in range(50, 100):
    print(data['Text'][i])
# Out:
# Every time I log out of the application, and log back in, the checkout cart clears my basket history.  This is very frustrating.
# Every time I try to checkout and submit the order, the screen just spins as a buffer, and I have to restart
# Everything on your website is super expensive.  Do you have any coupons or discounts?
# Exactly what I wanted, and it came much earlier then expected. Thank you so much!
# For $100, I expected a high quality lamp.  Can we start a return, and how can I get refunded?
# For an appliciance that was supposed to have high-end features, this dishwasher is a piece of junk.
# Half of the time your website doesn't work. How can I order things if it isn't reliable? FIX IT!
# Half the time, the dishwasher isn't reliable, stops the cycle early, and leaves food bits on my dishes
# Happily married but happily reparing everything that I buy from you guys, would love to get someone to actually fix something.
# Having issues checking out with PayPal.
# Help! My account was hacked!
# Home Depot is offering this same garden gnome for $5 less. Can you apply a competitors' discount?
# How can I reload my giftcard online?
# How can I sort throught the products on the website and get the best sellers at the top?
# How can I track where my package is currently?
# How can I update my address on the login page?
# How come none of your washing machines have features that Home Depot's does?  I need to shop there instead until you can get good merchandise
# How do the installation services work? It is unclear to me.
# How early can I get my microwave delivered to me?
# How is it that life is so difficult with your support team? I've tried to contact you a million times in the last few weeks regarding my headphones, I guess nobody was in office.
# How long does it take to get my money back after I shipped it back for returns?
# How much are the installation services?
# How much would a consultation cost for window installation?
# I am trying to look for a dining table with the dimensions 78 in in length and 30 in height.
# I am unable to add my credit card, an error keeps popping up.
# I called to report a price change in the middle of my transaction.  Although the change was small, I didn't think this was fair.  The support team corrected the issue, and I am thankful for that. But this should not happen again.
# I called to reset my password, but the account services team was incompetent
# I can not locate the search bar to find a certain product.
# I can see why these curtain rods were so cheap - they basically broke in half while I was trying to install them.  Can you either send me new ones or some that aren't so janky?
# I cannot add in my coupons easily on the website.
# I cannot locate the total price of all the items I selected.
# I can't find any statement regarding how you handle my personal information. Do you have an information security guideline in the company that you could guide me to?
# I can't find my warrenty number for the ice maker that I bought 2 months ago. Will you search for it in your online systems?
# I can't tell if my dresser is coming at a specific time tomorrow. I need to know.
# I chose UPS ground shipping but actually need my items much faster.  Can you help me upgrade to expedited overnight shipping?
# I completely hate how your website looks and functions!
# I did an analysis on our prices vs. the competitors. In appliances we charge 3% less on average, but in homegoods we are charging 5% more. How can we balance this?
# I do not like the quality of the dining table I just purchansed, which other brands in kitchen tables do you sell?
# I don't know what to say about the speed of delivery, because I still haven't received my package!!!
# I don't like how everytime I shop on this website I need to check prices against other merchants, its stupid.
# I feel like your costs are so inflated. Do not recommend to my friends.
# I forgot my password.  Do you have a password reset link?
# I get that this kind of devices, we donít need them to look pretty. But , Yellow?? As the color of the unit is just wrong design choice.
# I got billed the wrong amount for this garden hose. Can this get corrected immediately?
# I got my order split in half. I have received part of my order when will I get the other part?
# i had to wait 23 minutes to talk to an agent.
# I have been tracking my shipment and it shows that it has been sitting in a warehouse for past 4 days. Will I get my order in time? Is there a problem with my order?
# I have been waiting for confirmation email but I haven't received it. What would you recommend?
# I have been waiting to get my order for 3 weeks now and no one is picking up in customer service! What do I do?
# I have being using this device for a year and I like it. I just need to change the door hinges. Would you be able to send me a pair of hinges for this unit?

# %%
data.groupby('CustomerID').count()[['SupportTicketID']].sort_values('SupportTicketID', ascending = False)
# Out:
#             SupportTicketID
# CustomerID
# 10022074                  2
# 10042279                  2
# 10000069                  1
# 10026988                  1
# 10028448                  1
# ...                     ...
# 10013924                  1
# 10013566                  1
# 10013489                  1
# 10013412                  1
# 10045151                  1
#
# [326 rows x 1 columns]

# %%
data[data['CustomerID'].isin(['10022074', '10042279'])]
# Out:
#      SupportTicketID  CustomerID DateCreated DateCompleted  Escalated  \
# 29            108388    10042279  2018-05-27    2018-05-06          0
# 148           108385    10042279  2018-01-12    2018-10-12          1
# 294            52172    10022074  2018-04-11    2018-08-11          0
# 326            52174    10022074  2018-03-06    2018-03-06          1
#
#         Theme                                         Theme_Desc  \
# 29   features  product features, website features, checkout f...
# 148  features  product features, website features, checkout f...
# 294  features  product features, website features, checkout f...
# 326  features  product features, website features, checkout f...
#
#                                                   Text  Process Time
# 29                 Can your notebooks have more grids?           -21
# 148  I wish there was a way to cancel my order afte...           273
# 294          Where can I find the FAQ on your website?           122
# 326  Your website's check out system bugs when I us...             0

# %%
data.groupby('Theme').mean()
# Out:
#              SupportTicketID    CustomerID  Escalated  Process Time
# Theme
# design          40997.666667  1.001740e+07   0.111111    -13.944444
# features        51004.040816  1.002109e+07   0.081633      7.755102
# other           52437.076923  1.002132e+07   0.307692    -14.538462
# price           44565.847458  1.001855e+07   0.067797     -2.711864
# reliability     62450.290323  1.002562e+07   0.161290     24.838710
# security        69768.692308  1.002779e+07   0.153846     16.615385
# services        48129.882353  1.002007e+07   0.147059     23.411765
# speed           56560.454545  1.002318e+07   0.129870      0.909091
# support         61904.380952  1.002547e+07   0.095238     -9.476190

# %%
data[data['Theme'] == 'other']
# Out:
#      SupportTicketID  CustomerID DateCreated DateCompleted  Escalated  Theme  \
# 39            124769    10044918  2018-12-05    2018-05-17          1  other
# 48             56718    10023981  2018-04-08    2018-05-08          1  other
# 109            22616    10009722  2018-08-18    2018-08-18          0  other
# 132             7932    10003450  2018-08-16    2018-08-20          0  other
# 151           105836    10041864  2018-10-27    2018-10-29          0  other
# 156            99464    10040860  2018-10-31    2018-08-11          1  other
# 160            53990    10022819  2018-12-06    2018-06-20          0  other
# 187            39794    10016909  2018-10-27    2018-10-29          1  other
# 199            52263    10022104  2018-01-09    2018-05-09          0  other
# 252            31862    10013566  2018-09-18    2018-09-19          0  other
# 273            24540    10010510  2018-06-08    2018-12-08          0  other
# 281            41805    10017754  2018-04-06    2018-05-06          0  other
# 313            20093    10008685  2018-10-06    2018-06-19          0  other
#
#                   Theme_Desc  \
# 39   Just make up something!
# 48   Just make up something!
# 109  Just make up something!
# 132  Just make up something!
# 151  Just make up something!
# 156  Just make up something!
# 160  Just make up something!
# 187  Just make up something!
# 199  Just make up something!
# 252  Just make up something!
# 273  Just make up something!
# 281  Just make up something!
# 313  Just make up something!
#
#                                                   Text  Process Time
# 39   Do you have a brick-and-mortar store or are yo...          -202
# 48   Doorknob broke after one use. Now I'm locked i...            30
# 109  I heard that your organization is sponsoring a...             0
# 132  I really like the ìquick boilî feature. I just...             4
# 151  If I have purchased an item from another retai...             2
# 156  I'm moving into a new home, and I'm looking fo...           -81
# 160  Instead of the pliers I ordered, I got a hard ...          -169
# 187       Lol I hate your customer service as a whole.             2
# 199  My mom said she hated the curtains.  #disappoi...           120
# 252  The picture that I am uploading to the website...             1
# 273                                 This app is buggy.           183
# 281  What are the companys protection plans for a p...            30
# 313         You sent the wrong product. Make it right1          -109

# %%
data.groupby('Escalated').mean()
# Out:
#            SupportTicketID    CustomerID  Process Time
# Escalated
# 0             52625.576389  1.002168e+07      4.833333
# 1             60839.125000  1.002480e+07      6.425000

# %% [markdown]
# Data Cleaning:
#     - Group by the Theme and Escalated and take mean of positive values

# %% [markdown]
# ### Question: Given the customer text input, predict whether the ticket will need to be escalated and its estimated processing time.
