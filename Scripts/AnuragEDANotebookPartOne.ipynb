# %% [markdown]
# # <u>Looking into Factors that affect Escalation of Tickets</u>

# %%
from text_analytics import *
import pandas as pd

# %%
data = pd.read_csv('../Data/support_ticket_data.csv', encoding='Windows-1252')
data
# Out:
#      SupportTicketID  CustomerID DateCreated DateCompleted  Escalated  \
# 0              16582    10007217  30/06/2018      4/7/2018          1
# 1              13830    10005984  15/07/2018    18/07/2018          0
# 2              53794    10022738  14/10/2018    18/10/2018          0
# 3              95013    10040142   1/11/2018    10/11/2018          0
# 4              32660    10013924    6/6/2018      6/6/2018          1
# ..               ...         ...         ...           ...        ...
# 323           123579    10044731  21/09/2018    30/09/2018          0
# 324           101069    10041114   1/12/2018     6/12/2018          0
# 325            73065    10030954    3/6/2018      5/6/2018          0
# 326            52174    10022074    3/6/2018      3/6/2018          1
# 327            29179    10012482  14/07/2018    14/07/2018          0
#
#            Theme                                         Theme_Desc  \
# 0          price  cost of the goods to customers.  compare to co...
# 1          speed                       consider the delivery speed.
# 2       features  product features, website features, checkout f...
# 3          price  cost of the goods to customers.  compare to co...
# 4         design                     product design, website design
# ..           ...                                                ...
# 323  reliability  product reliability, website reliability, deli...
# 324  reliability  product reliability, website reliability, deli...
# 325  reliability  product reliability, website reliability, deli...
# 326     features  product features, website features, checkout f...
# 327        speed                       consider the delivery speed.
#
#                                                   Text
# 0    A screwdriver costs over a hundred dollars? Wh...
# 1      Anyway that I can rush overnight ship my order?
# 2    Are the shelves removable from the wine fridge...
# 3             Are there any Christmas sales coming up?
# 4    Are there any other colors in the bathroom sin...
# ..                                                 ...
# 323  Your website is super glitchy. It won't let me...
# 324  Your website keeps crashing and forgetting eve...
# 325   Your website keeps crashing on mobile. It sucks.
# 326  Your website's check out system bugs when I us...
# 327                                                NaN
#
# [328 rows x 8 columns]

# %%
def text_json(text):
    
    documents = {"documents": [
        {"id": "1", "language": "en",
            "text": text}
    ]}
    return documents

def sentiment(documents):
    sentiments = sentiment_analysis_example(documents)
    x = list(map(lambda x: x["sentiment"], sentiments['documents']))
    return x

# %%
arr = []
for x in data['Text']:
    a = text_json(x)
    arr.append(sentiment(a))
data['Sentiment'] = arr
# Out:
# Printing sentiments ...
#
# {'documents': [{'confidenceScores': {'negative': 0.53,
#                                      'neutral': 0.46,
#                                      'positive': 0.01},
#                 'id': '1',
#                 'sentences': [{'confidenceScores': {'negative': 0.09,
#                                                     'neutral': 0.89,
#                                                     'positive': 0.02},
#                                'length': 43,
#                                'offset': 0,
#                                'sentiment': 'neutral',
#                                'text': 'A screwdriver costs over a hundred '
#                                        'dollars?'},
#                               {'confidenceScores': {'negative': 0.53,
#                                                     'neutral': 0.46,
#                                                     'positive': 0.01},
#                                'length': 32,
#                                'offset': 44,
#                                'sentiment': 'negative',
#                                'text': 'Why are your prices so inflated.'}],
#                 'sentiment': 'negative',
#                 'warnings': []}],
#  'errors': [],
#  'modelVersion': '2020-04-01'}
# Printing sentiments ...
#
# {'documents': [{'confidenceScores': {'negative': 0.09,
#                                      'neutral': 0.9,
#                                      'positive': 0.01},
#                 'id': '1',
#                 'sentences': [{'confidenceScores': {'negative': 0.09,
#                                                     'neutral': 0.9,
#                                                     'positive': 0.01},
#                                'length': 47,
#                                'offset': 0,
#                                'sentiment': 'neutral',
#                                'text': 'Anyway that I can rush overnight ship '
#                                        'my order?'}],
#                 'sentiment': 'neutral',
#                 'warnings': []}],
#  'errors': [],
#  'modelVersion': '2020-04-01'}
# Printing sentiments ...
#
# {'documents': [{'confidenceScores': {'negative': 0.0,
#                                      'neutral': 0.99,
#                                      'positive': 0.01},
#                 'id': '1',
#                 'sentences': [{'confidenceScores': {'negative': 0.0,
#                                                     'neutral': 1.0,
#                                                     'positive': 0.0},
#                                'length': 47,
#                                'offset': 0,
#                                'sentiment': 'neutral',
#                                'text': 'Are the shelves removable from the '
#                                        'wine fridge?'},
#                               {'confidenceScores': {'negative': 0.0,
#                                                     'neutral': 0.99,
#                                                     'positive': 0.01},
#                                'length': 29,
#                                'offset': 48,
#                                'sentiment': 'neutral',
#                                'text': 'How many bottles can I store?'}],
#                 'sentiment': 'neutral',
#                 'warnings': []}],
#  'errors': [],
#  'modelVersion': '2020-04-01'}
# Printing sentiments ...
#
# {'documents': [{'confidenceScores': {'negative': 0.02,
#                                      'neutral': 0.96,
#                                      'positive': 0.02},
#                 'id': '1',
#                 'sentences': [{'confidenceScores': {'negative': 0.02,
#                                                     'neutral': 0.96,
#                                                     'positive': 0.02},
#                                'length': 40,
#                                'offset': 0,
#                                'sentiment': 'neutral',
#                                'text': 'Are there any Christmas sales coming '
#                                        'up?'}],
#                 'sentiment': 'neutral',
#                 'warnings': []}],
#  'errors': [],
#  'modelVersion': '2020-04-01'}
# Printing sentiments ...
#
# {'documents': [{'confidenceScores': {'negative': 0.0,
#                                      'neutral': 1.0,
#                                      'positive': 0.0},
#                 'id': '1',
#                 'sentences': [{'confidenceScores': {'negative': 0.0,
#                                                     'neutral': 1.0,
#                                                     'positive': 0.0},
#                                'length': 55,
#                                'offset': 0,
#                                'sentiment': 'neutral',
#                                'text': 'Are there any other colors in the '
#                                        'bathroom sink faucet?'}],
#                 'sentiment': 'neutral',
#                 'warnings': []}],
#  'errors': [],
#  'modelVersion': '2020-04-01'}
# Printing sentiments ...
#
# {'documents': [{'confidenceScores': {'negative': 0.01,
#                                      'neutral': 0.99,
#                                      'positive': 0.0},
#                 'id': '1',
#                 'sentences': [{'confidenceScores': {'negative': 0.01,
#                                                     'neutral': 0.99,
#                                                     'positive': 0.0},
#                                'length': 55,
#                                'offset': 0,
#                                'sentiment': 'neutral',
#                                'text': 'Are there warranties provided on '
#                                        'certain installations?'}],
#                 'sentiment': 'neutral',
#                 'warnings': []}],
#  'errors': [],
#  'modelVersion': '2020-04-01'}
# Printing sentiments ...
#
# {'documents': [{'confidenceScores': {'negative': 0.0,
#                                      'neutral': 0.0,
#                                      'positive': 1.0},
#                 'id': '1',
#                 'sentences': [{'confidenceScores': {'negative': 0.0,
#                                                     'neutral': 0.0,
#                                                     'positive': 1.0},
#                                'length': 32,
#                                'offset': 0,
#                                'sentiment': 'positive',
#                                'text': 'Are these good for one time use?'},
#                               {'confidenceScores': {'negative': 0.04,
#                                                     'neutral': 0.95,
#                                                     'positive': 0.01},
#                                'length': 49,
#                                'offset': 33,
#                                'sentiment': 'neutral',
#                                'text': 'I have used it once and now it is not '
#                                        'turning on?'},
#                               {'confidenceScores': {'negative': 0.01,
#                                                     'neutral': 0.94,
#                                                     'positive': 0.05},
#                                'length': 21,
#                                'offset': 83,
#                                'sentiment': 'neutral',
#                                'text': 'So what do we do now?'}],
#                 'sentiment': 'positive',
#                 'warnings': []}],
#  'errors': [],
#  'modelVersion': '2020-04-01'}
# Printing sentiments ...
#
# {'documents': [{'confidenceScores': {'negative': 0.0,
#                                      'neutral': 1.0,
#                                      'positive': 0.0},
#                 'id': '1',
#                 'sentences': [{'confidenceScores': {'negative': 0.0,
#                                                     'neutral': 1.0,
#                                                     'positive': 0.0},
#                                'length': 90,
#                                'offset': 0,
#                                'sentiment': 'neutral',
#                                'text': 'Are you able to price match on a '
#                                        'washer machine that I found online '
#                                        'from another retailer?'}],
#                 'sentiment': 'neutral',
#                 'warnings': []}],
#  'errors': [],
#  'modelVersion': '2020-04-01'}
# Printing sentiments ...
#
# {'documents': [{'confidenceScores': {'negative': 0.01,
#                                      'neutral': 0.92,
#                                      'positive': 0.07},
#                 'id': '1',
#                 'sentences': [{'confidenceScores': {'negative': 0.01,
#                                                     'neutral': 0.92,
#                                                     'positive': 0.07},
#                                'length': 47,
#                                'offset': 0,
#                                'sentiment': 'neutral',
#                                'text': 'Are you guys delivering with donkeys '
#                                        'or horses?'}],
#                 'sentiment': 'neutral',
#                 'warnings': []}],
#  'errors': [],
#  'modelVersion': '2020-04-01'}
# Printing sentiments ...
#
# {'documents': [{'confidenceScores': {'negative': 1.0,
#                                      'neutral': 0.0,
#                                      'positive': 0.0},
#                 'id': '1',
#                 'sentences': [{'confidenceScores': {'negative': 0.01,
#                                                     'neutral': 0.95,
#                                                     'positive': 0.04},
#                                'length': 54,
#                                'offset': 0,
#                                'sentiment': 'neutral',
#                                'text': 'Are you using horses and buggies to '
#                                        'delivery my goods?'},
#                               {'confidenceScores': {'negative': 1.0,
#                                                     'neutral': 0.0,
#                                                     'positive': 0.0},
#                                'length': 46,
#                                'offset': 56,
#                                'sentiment': 'negative',
#                                'text': 'The shipping speed is completely '
#                                        'unacceptable.'}],
#                 'sentiment': 'negative',
#                 'warnings': []}],
#  'errors': [],
#  'modelVersion': '2020-04-01'}
# Printing sentiments ...
#
# {'documents': [{'confidenceScores': {'negative': 0.56,
#                                      'neutral': 0.39,
#                                      'positive': 0.05},
#                 'id': '1',
#                 'sentences': [{'confidenceScores': {'negative': 0.56,
#                                                     'neutral': 0.39,
#                                                     'positive': 0.05},
#                                'length': 32,
#                                'offset': 0,
#                                'sentiment': 'negative',
#                                'text': 'Been waiting for almost a month.'},
#                               {'confidenceScores': {'negative': 0.01,
#                                                     'neutral': 0.95,
#                                                     'positive': 0.04},
#                                'length': 35,
#                                'offset': 33,
#                                'sentiment': 'neutral',
#                                'text': 'Did you guys forget about my order?'}],
#                 'sentiment': 'negative',
#                 'warnings': []}],
#  'errors': [],
#  'modelVersion': '2020-04-01'}
# Printing sentiments ...
#
# {'documents': [{'confidenceScores': {'negative': 0.01,
#                                      'neutral': 0.99,
#                                      'positive': 0.0},
#                 'id': '1',
#                 'sentences': [{'confidenceScores': {'negative': 0.01,
#                                                     'neutral': 0.99,
#                                                     'positive': 0.0},
#                                'length': 103,
#                                'offset': 0,
#                                'sentiment': 'neutral',
#                                'text': 'Can I add a backup email address since '
#                                        'I am not getting any emails on the one '
#                                        'registered to my account?'}],
#                 'sentiment': 'neutral',
#                 'warnings': []}],
#  'errors': [],
#  'modelVersion': '2020-04-01'}
# Printing sentiments ...
#
# {'documents': [{'confidenceScores': {'negative': 0.03,
#                                      'neutral': 0.88,
#                                      'positive': 0.09},
#                 'id': '1',
#                 'sentences': [{'confidenceScores': {'negative': 0.03,
#                                                     'neutral': 0.88,
#                                                     'positive': 0.09},
#                                'length': 73,
#                                'offset': 0,
#                                'sentiment': 'neutral',
#                                'text': 'Can I add in more than one credit card '
#                                        'in my account for payment methods?'}],
#                 'sentiment': 'neutral',
#                 'warnings': []}],
#  'errors': [],
#  'modelVersion': '2020-04-01'}
# Printing sentiments ...
#
# {'documents': [{'confidenceScores': {'negative': 0.77,
#                                      'neutral': 0.23,
#                                      'positive': 0.0},
#                 'id': '1',
#                 'sentences': [{'confidenceScores': {'negative': 0.77,
#                                                     'neutral': 0.23,
#                                                     'positive': 0.0},
#                                'length': 70,
#                                'offset': 0,
#                                'sentiment': 'negative',
#                                'text': 'Can I buy a warranty for a product I '
#                                        'just purchased or is it too late?'}],
#                 'sentiment': 'negative',
#                 'warnings': []}],
#  'errors': [],
#  'modelVersion': '2020-04-01'}
# Printing sentiments ...
#
# {'documents': [{'confidenceScores': {'negative': 0.89,
#                                      'neutral': 0.11,
#                                      'positive': 0.0},
#                 'id': '1',
#                 'sentences': [{'confidenceScores': {'negative': 0.89,
#                                                     'neutral': 0.11,
#                                                     'positive': 0.0},
#                                'length': 56,
#                                'offset': 0,
#                                'sentiment': 'negative',
#                                'text': 'Can I change my password, my current '
#                                        'one is not working.'}],
#                 'sentiment': 'negative',
#                 'warnings': []}],
#  'errors': [],
#  'modelVersion': '2020-04-01'}
# Printing sentiments ...
#
# {'documents': [{'confidenceScores': {'negative': 0.02,
#                                      'neutral': 0.98,
#                                      'positive': 0.0},
#                 'id': '1',
#                 'sentences': [{'confidenceScores': {'negative': 0.02,
#                                                     'neutral': 0.98,
#                                                     'positive': 0.0},
#                                'length': 51,
#                                'offset': 0,
#                                'sentiment': 'neutral',
#                                'text': 'Can I delete one of the credit cards '
#                                        'on my account?'}],
#                 'sentiment': 'neutral',
#                 'warnings': []}],
#  'errors': [],
#  'modelVersion': '2020-04-01'}
# Printing sentiments ...
#
# {'documents': [{'confidenceScores': {'negative': 0.01,
#                                      'neutral': 0.99,
#                                      'positive': 0.0},
#                 'id': '1',
#                 'sentences': [{'confidenceScores': {'negative': 0.01,
#                                                     'neutral': 0.99,
#                                                     'positive': 0.0},
#                                'length': 43,
#                                'offset': 0,
#                                'sentiment': 'neutral',
#                                'text': 'Can I get a  giftcard for the store '
#                                        'online?'}],
#                 'sentiment': 'neutral',
#                 'warnings': []}],
#  'errors': [],
#  'modelVersion': '2020-04-01'}
# Printing sentiments ...
#
# {'documents': [{'confidenceScores': {'negative': 0.03,
#                                      'neutral': 0.92,
#                                      'positive': 0.05},
#                 'id': '1',
#                 'sentences': [{'confidenceScores': {'negative': 0.03,
#                                                     'neutral': 0.92,
#                                                     'positive': 0.05},
#                                'length': 86,
#                                'offset': 0,
#                                'sentiment': 'neutral',
#                                'text': 'Can I get a quote for how much it will '
#                                        'cost to get your team to assemble my '
#                                        'furniture?'}],
#                 'sentiment': 'neutral',
#                 'warnings': []}],
#  'errors': [],
#  'modelVersion': '2020-04-01'}
# Printing sentiments ...
#
# {'documents': [{'confidenceScores': {'negative': 0.48,
#                                      'neutral': 0.51,
#                                      'positive': 0.01},
#                 'id': '1',
#                 'sentences': [{'confidenceScores': {'negative': 0.48,
#                                                     'neutral': 0.51,
#                                                     'positive': 0.01},
#                                'length': 69,
#                                'offset': 0,
#                                'sentiment': 'neutral',
#                                'text': 'Can I get a refund for my product '
#                                        'since it was never delivered to me?'}],
#                 'sentiment': 'neutral',
#                 'warnings': []}],
#  'errors': [],
#  'modelVersion': '2020-04-01'}
# Printing sentiments ...
#
# {'documents': [{'confidenceScores': {'negative': 0.02,
#                                      'neutral': 0.97,
#                                      'positive': 0.01},
#                 'id': '1',
#                 'sentences': [{'confidenceScores': {'negative': 0.02,
#                                                     'neutral': 0.97,
#                                                     'positive': 0.01},
#                                'length': 63,
#                                'offset': 0,
#                                'sentiment': 'neutral',
#                                'text': 'Can I get an estimate for when my item '
#                                        'will be delivered to me?'}],
#                 'sentiment': 'neutral',
#                 'warnings': []}],
#  'errors': [],
#  'modelVersion': '2020-04-01'}
# Printing sentiments ...
#
# {'documents': [{'confidenceScores': {'negative': 0.03,
#                                      'neutral': 0.96,
#                                      'positive': 0.01},
#                 'id': '1',
#                 'sentences': [{'confidenceScores': {'negative': 0.03,
#                                                     'neutral': 0.96,
#                                                     'positive': 0.01},
#                                'length': 77,
#                                'offset': 0,
#                                'sentiment': 'neutral',
#                                'text': 'Can I reroute my refund for the '
#                                        'private to a different offshore bank '
#                                        'account?'}],
#                 'sentiment': 'neutral',
#                 'warnings': []}],
#  'errors': [],
#  'modelVersion': '2020-04-01'}
# Printing sentiments ...
#
# {'documents': [{'confidenceScores': {'negative': 0.01,
#                                      'neutral': 0.94,
#                                      'positive': 0.05},
#                 'id': '1',
#                 'sentences': [{'confidenceScores': {'negative': 0.01,
#                                                     'neutral': 0.94,
#                                                     'positive': 0.05},
#                                'length': 53,
#                                'offset': 0,
#                                'sentiment': 'neutral',
#                                'text': 'Can I schedule my delievery for '
#                                        'another time and day?'}],
#                 'sentiment': 'neutral',
#                 'warnings': []}],
#  'errors': [],
#  'modelVersion': '2020-04-01'}
# Printing sentiments ...
#
# {'documents': [{'confidenceScores': {'negative': 0.08,
#                                      'neutral': 0.87,
#                                      'positive': 0.05},
#                 'id': '1',
#                 'sentences': [{'confidenceScores': {'negative': 0.08,
#                                                     'neutral': 0.87,
#                                                     'positive': 0.05},
#                                'length': 59,
#                                'offset': 0,
#                                'sentiment': 'neutral',
#                                'text': 'Can the delivery man leave my item on '
#                                        'the curbside instead?'}],
#                 'sentiment': 'neutral',
#                 'warnings': []}],
#  'errors': [],
#  'modelVersion': '2020-04-01'}
# Printing sentiments ...
#
# {'documents': [{'confidenceScores': {'negative': 0.0,
#                                      'neutral': 0.01,
#                                      'positive': 0.99},
#                 'id': '1',
#                 'sentences': [{'confidenceScores': {'negative': 0.0,
#                                                     'neutral': 0.98,
#                                                     'positive': 0.02},
#                                'length': 100,
#                                'offset': 0,
#                                'sentiment': 'neutral',
#                                'text': 'Can you please add VR features to your '
#                                        'mobile app so that I can actually '
#                                        'envision things in my home?'},
#                               {'confidenceScores': {'negative': 0.0,
#                                                     'neutral': 0.01,
#                                                     'positive': 0.99},
#                                'length': 26,
#                                'offset': 102,
#                                'sentiment': 'positive',
#                                'text': 'That would be really cool.'}],
#                 'sentiment': 'positive',
#                 'warnings': []}],
#  'errors': [],
#  'modelVersion': '2020-04-01'}
# Printing sentiments ...
#
# {'documents': [{'confidenceScores': {'negative': 0.0,
#                                      'neutral': 1.0,
#                                      'positive': 0.0},
#                 'id': '1',
#                 'sentences': [{'confidenceScores': {'negative': 0.0,
#                                                     'neutral': 1.0,
#                                                     'positive': 0.0},
#                                'length': 68,
#                                'offset': 0,
#                                'sentiment': 'neutral',
#                                'text': 'Can you price match me on an oven that '
#                                        'I found at Lowes for cheaper?'}],
#                 'sentiment': 'neutral',
#                 'warnings': []}],
#  'errors': [],
#  'modelVersion': '2020-04-01'}
# Printing sentiments ...
#
# {'documents': [{'confidenceScores': {'negative': 0.01,
#                                      'neutral': 0.95,
#                                      'positive': 0.04},
#                 'id': '1',
#                 'sentences': [{'confidenceScores': {'negative': 0.01,
#                                                     'neutral': 0.95,
#                                                     'positive': 0.04},
#                                'length': 49,
#                                'offset': 0,
#                                'sentiment': 'neutral',
#                                'text': 'Can you price match these pliers from '
#                                        'Home Depot?'}],
#                 'sentiment': 'neutral',
#                 'warnings': []}],
#  'errors': [],
#  'modelVersion': '2020-04-01'}
# Printing sentiments ...
#
# {'documents': [{'confidenceScores': {'negative': 0.01,
#                                      'neutral': 0.98,
#                                      'positive': 0.01},
#                 'id': '1',
#                 'sentences': [{'confidenceScores': {'negative': 0.02,
#                                                     'neutral': 0.97,
#                                                     'positive': 0.01},
#                                'length': 78,
#                                'offset': 0,
#                                'sentiment': 'neutral',
#                                'text': 'Can you provide the specific time when '
#                                        'my shovel is supposed to get '
#                                        'delivered?'},
#                               {'confidenceScores': {'negative': 0.01,
#                                                     'neutral': 0.98,
#                                                     'positive': 0.01},
#                                'length': 15,
#                                'offset': 79,
#                                'sentiment': 'neutral',
#                                'text': 'I have no clue.'}],
#                 'sentiment': 'neutral',
#                 'warnings': []}],
#  'errors': [],
#  'modelVersion': '2020-04-01'}
# Printing sentiments ...
#
# {'documents': [{'confidenceScores': {'negative': 0.04,
#                                      'neutral': 0.95,
#                                      'positive': 0.01},
#                 'id': '1',
#                 'sentences': [{'confidenceScores': {'negative': 0.04,
#                                                     'neutral': 0.95,
#                                                     'positive': 0.01},
#                                'length': 57,
#                                'offset': 0,
#                                'sentiment': 'neutral',
#                                'text': 'Can you replace a product if you are '
#                                        'unable to repair it?'}],
#                 'sentiment': 'neutral',
#                 'warnings': []}],
#  'errors': [],
#  'modelVersion': '2020-04-01'}
# Printing sentiments ...
#
# {'documents': [{'confidenceScores': {'negative': 0.05,
#                                      'neutral': 0.84,
#                                      'positive': 0.11},
#                 'id': '1',
#                 'sentences': [{'confidenceScores': {'negative': 0.0,
#                                                     'neutral': 0.99,
#                                                     'positive': 0.01},
#                                'length': 42,
#                                'offset': 0,
#                                'sentiment': 'neutral',
#                                'text': 'Can you send out someone for '
#                                        'installation?'},
#                               {'confidenceScores': {'negative': 0.1,
#                                                     'neutral': 0.7,
#                                                     'positive': 0.2},
#                                'length': 48,
#                                'offset': 44,
#                                'sentiment': 'neutral',
#                                'text': 'Thought I could do it myself but need '
#                                        'some help.'}],
#                 'sentiment': 'neutral',
#                 'warnings': []}],
#  'errors': [],
#  'modelVersion': '2020-04-01'}
# Printing sentiments ...
#
# {'documents': [{'confidenceScores': {'negative': 0.01,
#                                      'neutral': 0.97,
#                                      'positive': 0.02},
#                 'id': '1',
#                 'sentences': [{'confidenceScores': {'negative': 0.01,
#                                                     'neutral': 0.97,
#                                                     'positive': 0.02},
#                                'length': 35,
#                                'offset': 0,
#                                'sentiment': 'neutral',
#                                'text': 'Can your notebooks have more grids?'}],
#                 'sentiment': 'neutral',
#                 'warnings': []}],
#  'errors': [],
#  'modelVersion': '2020-04-01'}
# Printing sentiments ...
#
# {'documents': [{'confidenceScores': {'negative': 0.01,
#                                      'neutral': 0.03,
#                                      'positive': 0.96},
#                 'id': '1',
#                 'sentences': [{'confidenceScores': {'negative': 0.02,
#                                                     'neutral': 0.92,
#                                                     'positive': 0.06},
#                                'length': 18,
#                                'offset': 0,
#                                'sentiment': 'neutral',
#                                'text': 'Curtains for $105?'},
#                               {'confidenceScores': {'negative': 0.01,
#                                                     'neutral': 0.03,
#                                                     'positive': 0.96},
#                                'length': 79,
#                                'offset': 19,
#                                'sentiment': 'positive',
#                                'text': "You're kidding right - I can get these "
#                                        'from Bed Bath & Beyond for much '
#                                        'cheaper.'}],
#                 'sentiment': 'positive',
#                 'warnings': []}],
#  'errors': [],
#  'modelVersion': '2020-04-01'}
# Printing sentiments ...
#
# {'documents': [{'confidenceScores': {'negative': 1.0,
#                                      'neutral': 0.0,
#                                      'positive': 0.0},
#                 'id': '1',
#                 'sentences': [{'confidenceScores': {'negative': 1.0,
#                                                     'neutral': 0.0,
#                                                     'positive': 0.0},
#                                'length': 61,
#                                'offset': 0,
#                                'sentiment': 'negative',
#                                'text': 'Delivery got here way too early, so '
#                                        'someone stole my package.'}],
#                 'sentiment': 'negative',
#                 'warnings': []}],
#  'errors': [],
#  'modelVersion': '2020-04-01'}
# Printing sentiments ...
#
# {'documents': [{'confidenceScores': {'negative': 0.99,
#                                      'neutral': 0.01,
#                                      'positive': 0.0},
#                 'id': '1',
#                 'sentences': [{'confidenceScores': {'negative': 0.99,
#                                                     'neutral': 0.01,
#                                                     'positive': 0.0},
#                                'length': 32,
#                                'offset': 0,
#                                'sentiment': 'negative',
#                                'text': 'Delivery was exceptionally late.'},
#                               {'confidenceScores': {'negative': 0.04,
#                                                     'neutral': 0.95,
#                                                     'positive': 0.01},
#                                'length': 93,
#                                'offset': 34,
#                                'sentiment': 'neutral',
#                                'text': 'I reordered from somewhere else, so '
#                                        'can you have someone come pick up the '
#                                        'item and refund me?'}],
#                 'sentiment': 'negative',
#                 'warnings': []}],
#  'errors': [],
#  'modelVersion': '2020-04-01'}
# Printing sentiments ...
#
# {'documents': [{'confidenceScores': {'negative': 0.94,
#                                      'neutral': 0.05,
#                                      'positive': 0.01},
#                 'id': '1',
#                 'sentences': [{'confidenceScores': {'negative': 0.94,
#                                                     'neutral': 0.05,
#                                                     'positive': 0.01},
#                                'length': 37,
#                                'offset': 0,
#                                'sentiment': 'negative',
#                                'text': 'Devlivery speed was slow as '
#                                        'molasses.'}],
#                 'sentiment': 'negative',
#                 'warnings': []}],
#  'errors': [],
#  'modelVersion': '2020-04-01'}
# Printing sentiments ...
#
# {'documents': [{'confidenceScores': {'negative': 0.97,
#                                      'neutral': 0.03,
#                                      'positive': 0.0},
#                 'id': '1',
#                 'sentences': [{'confidenceScores': {'negative': 0.99,
#                                                     'neutral': 0.01,
#                                                     'positive': 0.0},
#                                'length': 61,
#                                'offset': 0,
#                                'sentiment': 'negative',
#                                'text': 'Did a bunch of morons design the '
#                                        'product features in my oven?'},
#                               {'confidenceScores': {'negative': 0.95,
#                                                     'neutral': 0.04,
#                                                     'positive': 0.01},
#                                'length': 19,
#                                'offset': 63,
#                                'sentiment': 'negative',
#                                'text': 'Like nothing works.'},
#                               {'confidenceScores': {'negative': 0.06,
#                                                     'neutral': 0.9,
#                                                     'positive': 0.04},
#                                'length': 4,
#                                'offset': 84,
#                                'sentiment': 'neutral',
#                                'text': 'Why.'}],
#                 'sentiment': 'negative',
#                 'warnings': []}],
#  'errors': [],
#  'modelVersion': '2020-04-01'}
# Printing sentiments ...
#
# {'documents': [{'confidenceScores': {'negative': 1.0,
#                                      'neutral': 0.0,
#                                      'positive': 0.0},
#                 'id': '1',
#                 'sentences': [{'confidenceScores': {'negative': 0.0,
#                                                     'neutral': 1.0,
#                                                     'positive': 0.0},
#                                'length': 47,
#                                'offset': 0,
#                                'sentiment': 'neutral',
#                                'text': 'Did you share my email info with third '
#                                        'parties?'},
#                               {'confidenceScores': {'negative': 1.0,
#                                                     'neutral': 0.0,
#                                                     'positive': 0.0},
#                                'length': 56,
#                                'offset': 49,
#                                'sentiment': 'negative',
#                                'text': "After I placed an order, I've been "
#                                        'getting so much spam.'}],
#                 'sentiment': 'negative',
#                 'warnings': []}],
#  'errors': [],
#  'modelVersion': '2020-04-01'}
# Printing sentiments ...
#
# {'documents': [{'confidenceScores': {'negative': 1.0,
#                                      'neutral': 0.0,
#                                      'positive': 0.0},
#                 'id': '1',
#                 'sentences': [{'confidenceScores': {'negative': 0.03,
#                                                     'neutral': 0.91,
#                                                     'positive': 0.06},
#                                'length': 51,
#                                'offset': 0,
#                                'sentiment': 'neutral',
#                                'text': 'Do these garden gnomes come with money '
#                                        'inside them?'},
#                               {'confidenceScores': {'negative': 1.0,
#                                                     'neutral': 0.0,
#                                                     'positive': 0.0},
#                                'length': 58,
#                                'offset': 52,
#                                'sentiment': 'negative',
#                                'text': "Is that why they're so much more "
#                                        "expensive than at Lowe's?"}],
#                 'sentiment': 'negative',
#                 'warnings': []}],
#  'errors': [],
#  'modelVersion': '2020-04-01'}
# Printing sentiments ...
#
# {'documents': [{'confidenceScores': {'negative': 0.01,
#                                      'neutral': 0.97,
#                                      'positive': 0.02},
#                 'id': '1',
#                 'sentences': [{'confidenceScores': {'negative': 0.01,
#                                                     'neutral': 0.97,
#                                                     'positive': 0.02},
#                                'length': 33,
#                                'offset': 0,
#                                'sentiment': 'neutral',
#                                'text': 'Do you guys match online pricing?'}],
#                 'sentiment': 'neutral',
#                 'warnings': []}],
#  'errors': [],
#  'modelVersion': '2020-04-01'}
# Printing sentiments ...
#
# {'documents': [{'confidenceScores': {'negative': 0.0,
#                                      'neutral': 1.0,
#                                      'positive': 0.0},
#                 'id': '1',
#                 'sentences': [{'confidenceScores': {'negative': 0.0,
#                                                     'neutral': 1.0,
#                                                     'positive': 0.0},
#                                'length': 43,
#                                'offset': 0,
#                                'sentiment': 'neutral',
#                                'text': 'Do you have 24/7 customer service '
#                                        'provided?'}],
#                 'sentiment': 'neutral',
#                 'warnings': []}],
#  'errors': [],
#  'modelVersion': '2020-04-01'}
# Printing sentiments ...
#
# {'documents': [{'confidenceScores': {'negative': 0.0,
#                                      'neutral': 0.0,
#                                      'positive': 1.0},
#                 'id': '1',
#                 'sentences': [{'confidenceScores': {'negative': 0.0,
#                                                     'neutral': 1.0,
#                                                     'positive': 0.0},
#                                'length': 60,
#                                'offset': 0,
#                                'sentiment': 'neutral',
#                                'text': 'Do you have a brick-and-mortar store '
#                                        'or are you only online?'},
#                               {'confidenceScores': {'negative': 0.0,
#                                                     'neutral': 0.0,
#                                                     'positive': 1.0},
#                                'length': 38,
#                                'offset': 61,
#                                'sentiment': 'positive',
#                                'text': 'Would love to go to a store in '
#                                        'person.'}],
#                 'sentiment': 'positive',
#                 'warnings': []}],
#  'errors': [],
#  'modelVersion': '2020-04-01'}
# Printing sentiments ...
#
# {'documents': [{'confidenceScores': {'negative': 0.04,
#                                      'neutral': 0.14,
#                                      'positive': 0.82},
#                 'id': '1',
#                 'sentences': [{'confidenceScores': {'negative': 0.0,
#                                                     'neutral': 1.0,
#                                                     'positive': 0.0},
#                                'length': 41,
#                                'offset': 0,
#                                'sentiment': 'neutral',
#                                'text': 'Do you offer 1-day shipping and '
#                                        'delivery?'},
#                               {'confidenceScores': {'negative': 0.04,
#                                                     'neutral': 0.14,
#                                                     'positive': 0.82},
#                                'length': 21,
#                                'offset': 42,
#                                'sentiment': 'positive',
#                                'text': 'I need this tomorrow.'}],
#                 'sentiment': 'positive',
#                 'warnings': []}],
#  'errors': [],
#  'modelVersion': '2020-04-01'}
# Printing sentiments ...
#
# {'documents': [{'confidenceScores': {'negative': 0.0,
#                                      'neutral': 0.99,
#                                      'positive': 0.01},
#                 'id': '1',
#                 'sentences': [{'confidenceScores': {'negative': 0.0,
#                                                     'neutral': 0.99,
#                                                     'positive': 0.01},
#                                'length': 31,
#                                'offset': 0,
#                                'sentiment': 'neutral',
#                                'text': 'Do you offer holiday discounts?'}],
#                 'sentiment': 'neutral',
#                 'warnings': []}],
#  'errors': [],
#  'modelVersion': '2020-04-01'}
# Printing sentiments ...
#
# {'documents': [{'confidenceScores': {'negative': 0.0,
#                                      'neutral': 1.0,
#                                      'positive': 0.0},
#                 'id': '1',
#                 'sentences': [{'confidenceScores': {'negative': 0.0,
#                                                     'neutral': 1.0,
#                                                     'positive': 0.0},
#                                'length': 47,
#                                'offset': 0,
#                                'sentiment': 'neutral',
#                                'text': 'Do you price match with local small '
#                                        'businesses?'}],
#                 'sentiment': 'neutral',
#                 'warnings': []}],
#  'errors': [],
#  'modelVersion': '2020-04-01'}
# Printing sentiments ...
#
# {'documents': [{'confidenceScores': {'negative': 0.06,
#                                      'neutral': 0.92,
#                                      'positive': 0.02},
#                 'id': '1',
#                 'sentences': [{'confidenceScores': {'negative': 0.0,
#                                                     'neutral': 0.99,
#                                                     'positive': 0.01},
#                                'length': 19,
#                                'offset': 0,
#                                'sentiment': 'neutral',
#                                'text': 'Do you price match?'},
#                               {'confidenceScores': {'negative': 0.12,
#                                                     'neutral': 0.86,
#                                                     'positive': 0.02},
#                                'length': 39,
#                                'offset': 20,
#                                'sentiment': 'neutral',
#                                'text': 'This table is half the cost at '
#                                        'Walmart!'}],
#                 'sentiment': 'neutral',
#                 'warnings': []}],
#  'errors': [],
#  'modelVersion': '2020-04-01'}
# Printing sentiments ...
#
# {'documents': [{'confidenceScores': {'negative': 0.0,
#                                      'neutral': 1.0,
#                                      'positive': 0.0},
#                 'id': '1',
#                 'sentences': [{'confidenceScores': {'negative': 0.0,
#                                                     'neutral': 1.0,
#                                                     'positive': 0.0},
#                                'length': 71,
#                                'offset': 0,
#                                'sentiment': 'neutral',
#                                'text': 'Do you provide a video consulatation '
#                                        'for installations within the home?'}],
#                 'sentiment': 'neutral',
#                 'warnings': []}],
#  'errors': [],
#  'modelVersion': '2020-04-01'}
# Printing sentiments ...
#
# {'documents': [{'confidenceScores': {'negative': 0.99,
#                                      'neutral': 0.01,
#                                      'positive': 0.0},
#                 'id': '1',
#                 'sentences': [{'confidenceScores': {'negative': 0.0,
#                                                     'neutral': 0.99,
#                                                     'positive': 0.01},
#                                'length': 34,
#                                'offset': 0,
#                                'sentiment': 'neutral',
#                                'text': 'Do you take competitors discounts?'},
#                               {'confidenceScores': {'negative': 0.99,
#                                                     'neutral': 0.01,
#                                                     'positive': 0.0},
#                                'length': 29,
#                                'offset': 35,
#                                'sentiment': 'negative',
#                                'text': "It's unclear on your website."}],
#                 'sentiment': 'negative',
#                 'warnings': []}],
#  'errors': [],
#  'modelVersion': '2020-04-01'}
# Printing sentiments ...
#
# {'documents': [{'confidenceScores': {'negative': 0.01,
#                                      'neutral': 0.99,
#                                      'positive': 0.0},
#                 'id': '1',
#                 'sentences': [{'confidenceScores': {'negative': 0.01,
#                                                     'neutral': 0.99,
#                                                     'positive': 0.0},
#                                'length': 95,
#                                'offset': 0,
#                                'sentiment': 'neutral',
#                                'text': 'Does this Microwave have the feature '
#                                        'where you can just hit a number and it '
#                                        'puts in the minute?'}],
#                 'sentiment': 'neutral',
#                 'warnings': []}],
#  'errors': [],
#  'modelVersion': '2020-04-01'}
# Printing sentiments ...
#
# {'documents': [{'confidenceScores': {'negative': 0.0,
#                                      'neutral': 1.0,
#                                      'positive': 0.0},
#                 'id': '1',
# ...
#                                        'same process like ten times.'},
#                               {'confidenceScores': {'negative': 1.0,
#                                                     'neutral': 0.0,
#                                                     'positive': 0.0},
#                                'length': 15,
#                                'offset': 66,
#                                'sentiment': 'negative',
#                                'text': 'So frustrating.'}],
#                 'sentiment': 'negative',
#                 'warnings': []}],
#  'errors': [],
#  'modelVersion': '2020-04-01'}
# Printing sentiments ...
#
# {'documents': [{'confidenceScores': {'negative': 0.99,
#                                      'neutral': 0.01,
#                                      'positive': 0.0},
#                 'id': '1',
#                 'sentences': [{'confidenceScores': {'negative': 0.07,
#                                                     'neutral': 0.92,
#                                                     'positive': 0.01},
#                                'length': 134,
#                                'offset': 0,
#                                'sentiment': 'neutral',
#                                'text': 'Your delivery guy was supposed to come '
#                                        'during a 4 hour window, and I stayed '
#                                        'home from work today so that I could '
#                                        'receive the delivery!'},
#                               {'confidenceScores': {'negative': 1.0,
#                                                     'neutral': 0.0,
#                                                     'positive': 0.0},
#                                'length': 66,
#                                'offset': 135,
#                                'sentiment': 'negative',
#                                'text': 'They were like 5 hours late, which was '
#                                        'a massive waste of my time.'},
#                               {'confidenceScores': {'negative': 0.98,
#                                                     'neutral': 0.01,
#                                                     'positive': 0.01},
#                                'length': 57,
#                                'offset': 203,
#                                'sentiment': 'negative',
#                                'text': 'You need to take the delivery service '
#                                        'fee off my balance.'}],
#                 'sentiment': 'negative',
#                 'warnings': []}],
#  'errors': [],
#  'modelVersion': '2020-04-01'}
# Printing sentiments ...
#
# {'documents': [{'confidenceScores': {'negative': 0.75,
#                                      'neutral': 0.25,
#                                      'positive': 0.0},
#                 'id': '1',
#                 'sentences': [{'confidenceScores': {'negative': 0.75,
#                                                     'neutral': 0.25,
#                                                     'positive': 0.0},
#                                'length': 85,
#                                'offset': 0,
#                                'sentiment': 'negative',
#                                'text': 'Your homepage says that all garden '
#                                        "supplies are 25% off but I don't see "
#                                        'the discount.'},
#                               {'confidenceScores': {'negative': 0.01,
#                                                     'neutral': 0.96,
#                                                     'positive': 0.03},
#                                'length': 23,
#                                'offset': 86,
#                                'sentiment': 'neutral',
#                                'text': 'Is it still applicable?'}],
#                 'sentiment': 'negative',
#                 'warnings': []}],
#  'errors': [],
#  'modelVersion': '2020-04-01'}
# Printing sentiments ...
#
# {'documents': [{'confidenceScores': {'negative': 0.06,
#                                      'neutral': 0.91,
#                                      'positive': 0.03},
#                 'id': '1',
#                 'sentences': [{'confidenceScores': {'negative': 0.0,
#                                                     'neutral': 0.99,
#                                                     'positive': 0.01},
#                                'length': 50,
#                                'offset': 0,
#                                'sentiment': 'neutral',
#                                'text': 'Your shipping process moves at '
#                                        'evolutionary speed.'},
#                               {'confidenceScores': {'negative': 0.13,
#                                                     'neutral': 0.83,
#                                                     'positive': 0.04},
#                                'length': 42,
#                                'offset': 52,
#                                'sentiment': 'neutral',
#                                'text': "It's been like 8 weeks - what's "
#                                        'happening?'}],
#                 'sentiment': 'neutral',
#                 'warnings': []}],
#  'errors': [],
#  'modelVersion': '2020-04-01'}
# Printing sentiments ...
#
# {'documents': [{'confidenceScores': {'negative': 0.02,
#                                      'neutral': 0.95,
#                                      'positive': 0.03},
#                 'id': '1',
#                 'sentences': [{'confidenceScores': {'negative': 0.0,
#                                                     'neutral': 0.99,
#                                                     'positive': 0.01},
#                                'length': 55,
#                                'offset': 0,
#                                'sentiment': 'neutral',
#                                'text': 'Your slogan says you will match your '
#                                        'competitors price.'},
#                               {'confidenceScores': {'negative': 0.01,
#                                                     'neutral': 0.96,
#                                                     'positive': 0.03},
#                                'length': 62,
#                                'offset': 57,
#                                'sentiment': 'neutral',
#                                'text': 'I found the exact product for a '
#                                        'cheaper price at another site.'},
#                               {'confidenceScores': {'negative': 0.04,
#                                                     'neutral': 0.9,
#                                                     'positive': 0.06},
#                                'length': 48,
#                                'offset': 121,
#                                'sentiment': 'neutral',
#                                'text': 'How do I get the price match guarantee '
#                                        'promised?'}],
#                 'sentiment': 'neutral',
#                 'warnings': []}],
#  'errors': [],
#  'modelVersion': '2020-04-01'}
# Printing sentiments ...
#
# {'documents': [{'confidenceScores': {'negative': 0.99,
#                                      'neutral': 0.01,
#                                      'positive': 0.0},
#                 'id': '1',
#                 'sentences': [{'confidenceScores': {'negative': 0.99,
#                                                     'neutral': 0.01,
#                                                     'positive': 0.0},
#                                'length': 38,
#                                'offset': 0,
#                                'sentiment': 'negative',
#                                'text': 'Your stores have inconsistent '
#                                        'pricing.'}],
#                 'sentiment': 'negative',
#                 'warnings': []}],
#  'errors': [],
#  'modelVersion': '2020-04-01'}
# Printing sentiments ...
#
# {'documents': [{'confidenceScores': {'negative': 0.05,
#                                      'neutral': 0.94,
#                                      'positive': 0.01},
#                 'id': '1',
#                 'sentences': [{'confidenceScores': {'negative': 0.08,
#                                                     'neutral': 0.92,
#                                                     'positive': 0.0},
#                                'length': 79,
#                                'offset': 0,
#                                'sentiment': 'neutral',
#                                'text': 'Your user community page is showing my '
#                                        "fulll name which I didn't consent to "
#                                        'it.'},
#                               {'confidenceScores': {'negative': 0.02,
#                                                     'neutral': 0.96,
#                                                     'positive': 0.02},
#                                'length': 58,
#                                'offset': 80,
#                                'sentiment': 'neutral',
#                                'text': 'How can I add a profile name different '
#                                        'than my real name ?'}],
#                 'sentiment': 'neutral',
#                 'warnings': []}],
#  'errors': [],
#  'modelVersion': '2020-04-01'}
# Printing sentiments ...
#
# {'documents': [{'confidenceScores': {'negative': 0.07,
#                                      'neutral': 0.92,
#                                      'positive': 0.01},
#                 'id': '1',
#                 'sentences': [{'confidenceScores': {'negative': 0.01,
#                                                     'neutral': 0.99,
#                                                     'positive': 0.0},
#                                'length': 57,
#                                'offset': 0,
#                                'sentiment': 'neutral',
#                                'text': "your website doesn't have all of the "
#                                        'inventory you carry.'},
#                               {'confidenceScores': {'negative': 0.13,
#                                                     'neutral': 0.86,
#                                                     'positive': 0.01},
#                                'length': 86,
#                                'offset': 58,
#                                'sentiment': 'neutral',
#                                'text': 'I have to call everytime to order what '
#                                        'I need because it is not listed on the '
#                                        'website.'}],
#                 'sentiment': 'neutral',
#                 'warnings': []}],
#  'errors': [],
#  'modelVersion': '2020-04-01'}
# Printing sentiments ...
#
# {'documents': [{'confidenceScores': {'negative': 1.0,
#                                      'neutral': 0.0,
#                                      'positive': 0.0},
#                 'id': '1',
#                 'sentences': [{'confidenceScores': {'negative': 1.0,
#                                                     'neutral': 0.0,
#                                                     'positive': 0.0},
#                                'length': 30,
#                                'offset': 0,
#                                'sentiment': 'negative',
#                                'text': 'Your website is super glitchy.'},
#                               {'confidenceScores': {'negative': 0.42,
#                                                     'neutral': 0.55,
#                                                     'positive': 0.03},
#                                'length': 32,
#                                'offset': 31,
#                                'sentiment': 'neutral',
#                                'text': "It won't let me finish my order."}],
#                 'sentiment': 'negative',
#                 'warnings': []}],
#  'errors': [],
#  'modelVersion': '2020-04-01'}
# Printing sentiments ...
#
# {'documents': [{'confidenceScores': {'negative': 0.95,
#                                      'neutral': 0.05,
#                                      'positive': 0.0},
#                 'id': '1',
#                 'sentences': [{'confidenceScores': {'negative': 0.95,
#                                                     'neutral': 0.05,
#                                                     'positive': 0.0},
#                                'length': 65,
#                                'offset': 0,
#                                'sentiment': 'negative',
#                                'text': 'Your website keeps crashing and '
#                                        'forgetting everything in my cart.'},
#                               {'confidenceScores': {'negative': 0.07,
#                                                     'neutral': 0.8,
#                                                     'positive': 0.13},
#                                'length': 18,
#                                'offset': 66,
#                                'sentiment': 'neutral',
#                                'text': "I'm so frusterated"}],
#                 'sentiment': 'negative',
#                 'warnings': []}],
#  'errors': [],
#  'modelVersion': '2020-04-01'}
# Printing sentiments ...
#
# {'documents': [{'confidenceScores': {'negative': 0.97,
#                                      'neutral': 0.03,
#                                      'positive': 0.0},
#                 'id': '1',
#                 'sentences': [{'confidenceScores': {'negative': 0.93,
#                                                     'neutral': 0.07,
#                                                     'positive': 0.0},
#                                'length': 38,
#                                'offset': 0,
#                                'sentiment': 'negative',
#                                'text': 'Your website keeps crashing on '
#                                        'mobile.'},
#                               {'confidenceScores': {'negative': 1.0,
#                                                     'neutral': 0.0,
#                                                     'positive': 0.0},
#                                'length': 9,
#                                'offset': 39,
#                                'sentiment': 'negative',
#                                'text': 'It sucks.'}],
#                 'sentiment': 'negative',
#                 'warnings': []}],
#  'errors': [],
#  'modelVersion': '2020-04-01'}
# Printing sentiments ...
#
# {'documents': [{'confidenceScores': {'negative': 0.01,
#                                      'neutral': 0.99,
#                                      'positive': 0.0},
#                 'id': '1',
#                 'sentences': [{'confidenceScores': {'negative': 0.01,
#                                                     'neutral': 0.99,
#                                                     'positive': 0.0},
#                                'length': 55,
#                                'offset': 0,
#                                'sentiment': 'neutral',
#                                'text': "Your website's check out system bugs "
#                                        'when I use a VISA.'}],
#                 'sentiment': 'neutral',
#                 'warnings': []}],
#  'errors': [],
#  'modelVersion': '2020-04-01'}
# Printing sentiments ...
#
# {'documents': [{'confidenceScores': {'negative': 0.05,
#                                      'neutral': 0.53,
#                                      'positive': 0.42},
#                 'id': '1',
#                 'sentences': [{'confidenceScores': {'negative': 0.05,
#                                                     'neutral': 0.53,
#                                                     'positive': 0.42},
#                                'length': 3,
#                                'offset': 0,
#                                'sentiment': 'neutral',
#                                'text': 'NaN'}],
#                 'sentiment': 'neutral',
#                 'warnings': []}],
#  'errors': [],
#  'modelVersion': '2020-04-01'}

# %%
data
# Out:
#      SupportTicketID  CustomerID DateCreated DateCompleted  Escalated  \
# 0              16582    10007217  30/06/2018      4/7/2018          1
# 1              13830    10005984  15/07/2018    18/07/2018          0
# 2              53794    10022738  14/10/2018    18/10/2018          0
# 3              95013    10040142   1/11/2018    10/11/2018          0
# 4              32660    10013924    6/6/2018      6/6/2018          1
# ..               ...         ...         ...           ...        ...
# 323           123579    10044731  21/09/2018    30/09/2018          0
# 324           101069    10041114   1/12/2018     6/12/2018          0
# 325            73065    10030954    3/6/2018      5/6/2018          0
# 326            52174    10022074    3/6/2018      3/6/2018          1
# 327            29179    10012482  14/07/2018    14/07/2018          0
#
#            Theme                                         Theme_Desc  \
# 0          price  cost of the goods to customers.  compare to co...
# 1          speed                       consider the delivery speed.
# 2       features  product features, website features, checkout f...
# 3          price  cost of the goods to customers.  compare to co...
# 4         design                     product design, website design
# ..           ...                                                ...
# 323  reliability  product reliability, website reliability, deli...
# 324  reliability  product reliability, website reliability, deli...
# 325  reliability  product reliability, website reliability, deli...
# 326     features  product features, website features, checkout f...
# 327        speed                       consider the delivery speed.
#
#                                                   Text   Sentiment
# 0    A screwdriver costs over a hundred dollars? Wh...  [negative]
# 1      Anyway that I can rush overnight ship my order?   [neutral]
# 2    Are the shelves removable from the wine fridge...   [neutral]
# 3             Are there any Christmas sales coming up?   [neutral]
# 4    Are there any other colors in the bathroom sin...   [neutral]
# ..                                                 ...         ...
# 323  Your website is super glitchy. It won't let me...  [negative]
# 324  Your website keeps crashing and forgetting eve...  [negative]
# 325   Your website keeps crashing on mobile. It sucks.  [negative]
# 326  Your website's check out system bugs when I us...   [neutral]
# 327                                                NaN   [neutral]
#
# [328 rows x 9 columns]

# %%
arr = []
for x in data['Sentiment']:
    string = ""
    arr.append(string.join(x))

# %%
data['Sentiment'] = arr

# %%
data
# Out:
#      SupportTicketID  CustomerID DateCreated DateCompleted  Escalated  \
# 0              16582    10007217  30/06/2018      4/7/2018          1
# 1              13830    10005984  15/07/2018    18/07/2018          0
# 2              53794    10022738  14/10/2018    18/10/2018          0
# 3              95013    10040142   1/11/2018    10/11/2018          0
# 4              32660    10013924    6/6/2018      6/6/2018          1
# ..               ...         ...         ...           ...        ...
# 323           123579    10044731  21/09/2018    30/09/2018          0
# 324           101069    10041114   1/12/2018     6/12/2018          0
# 325            73065    10030954    3/6/2018      5/6/2018          0
# 326            52174    10022074    3/6/2018      3/6/2018          1
# 327            29179    10012482  14/07/2018    14/07/2018          0
#
#            Theme                                         Theme_Desc  \
# 0          price  cost of the goods to customers.  compare to co...
# 1          speed                       consider the delivery speed.
# 2       features  product features, website features, checkout f...
# 3          price  cost of the goods to customers.  compare to co...
# 4         design                     product design, website design
# ..           ...                                                ...
# 323  reliability  product reliability, website reliability, deli...
# 324  reliability  product reliability, website reliability, deli...
# 325  reliability  product reliability, website reliability, deli...
# 326     features  product features, website features, checkout f...
# 327        speed                       consider the delivery speed.
#
#                                                   Text Sentiment
# 0    A screwdriver costs over a hundred dollars? Wh...  negative
# 1      Anyway that I can rush overnight ship my order?   neutral
# 2    Are the shelves removable from the wine fridge...   neutral
# 3             Are there any Christmas sales coming up?   neutral
# 4    Are there any other colors in the bathroom sin...   neutral
# ..                                                 ...       ...
# 323  Your website is super glitchy. It won't let me...  negative
# 324  Your website keeps crashing and forgetting eve...  negative
# 325   Your website keeps crashing on mobile. It sucks.  negative
# 326  Your website's check out system bugs when I us...   neutral
# 327                                                NaN   neutral
#
# [328 rows x 9 columns]

# %%
sentiment_count = data.groupby(['Sentiment']).count()[['SupportTicketID']] 
sentiment_count['SupportTicketID'] = sentiment_count['SupportTicketID']/sum(sentiment_count['SupportTicketID']) * 100
sentiment_count
# Out:
#            SupportTicketID
# Sentiment
# mixed             5.792683
# negative         43.292683
# neutral          39.634146
# positive         11.280488

# %% [markdown]
# About <strong>83%</strong> of support tickets are <strong>neutral</strong> or <strong>negative</strong>!

# %%
df = data.groupby(['Escalated', 'Sentiment']).count()[['SupportTicketID']]

# %%
temp = df.reset_index()

# %%
escalated_0 = temp[temp['Escalated'] == 0]
escalated_0['SupportTicketID'] = escalated_0['SupportTicketID'] / sum(escalated_0['SupportTicketID']) * 100
escalated_0
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#    Escalated Sentiment  SupportTicketID
# 0          0     mixed         5.902778
# 1          0  negative        42.013889
# 2          0   neutral        39.930556
# 3          0  positive        12.152778

# %%
escalated_1 = temp[temp['Escalated'] == 1]
escalated_1['SupportTicketID'] = escalated_1['SupportTicketID'] / sum(escalated_1['SupportTicketID']) * 100
escalated_1
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#    Escalated Sentiment  SupportTicketID
# 4          1     mixed              5.0
# 5          1  negative             52.5
# 6          1   neutral             37.5
# 7          1  positive              5.0

# %%
temp_arr = data['Sentiment']

# %%
data['DateCompleted'] = pd.to_datetime(data['DateCompleted'])
data['DateCreated'] = pd.to_datetime(data['DateCreated'])
data['Process Time'] = (data['DateCompleted'] - data['DateCreated']).dt.days
data
# Out:
#      SupportTicketID  CustomerID DateCreated DateCompleted  Escalated  \
# 0              16582    10007217  2018-06-30    2018-04-07          1
# 1              13830    10005984  2018-07-15    2018-07-18          0
# 2              53794    10022738  2018-10-14    2018-10-18          0
# 3              95013    10040142  2018-01-11    2018-10-11          0
# 4              32660    10013924  2018-06-06    2018-06-06          1
# ..               ...         ...         ...           ...        ...
# 323           123579    10044731  2018-09-21    2018-09-30          0
# 324           101069    10041114  2018-01-12    2018-06-12          0
# 325            73065    10030954  2018-03-06    2018-05-06          0
# 326            52174    10022074  2018-03-06    2018-03-06          1
# 327            29179    10012482  2018-07-14    2018-07-14          0
#
#            Theme                                         Theme_Desc  \
# 0          price  cost of the goods to customers.  compare to co...
# 1          speed                       consider the delivery speed.
# 2       features  product features, website features, checkout f...
# 3          price  cost of the goods to customers.  compare to co...
# 4         design                     product design, website design
# ..           ...                                                ...
# 323  reliability  product reliability, website reliability, deli...
# 324  reliability  product reliability, website reliability, deli...
# 325  reliability  product reliability, website reliability, deli...
# 326     features  product features, website features, checkout f...
# 327        speed                       consider the delivery speed.
#
#                                                   Text Sentiment  Process Time
# 0    A screwdriver costs over a hundred dollars? Wh...  negative           -84
# 1      Anyway that I can rush overnight ship my order?   neutral             3
# 2    Are the shelves removable from the wine fridge...   neutral             4
# 3             Are there any Christmas sales coming up?   neutral           273
# 4    Are there any other colors in the bathroom sin...   neutral             0
# ..                                                 ...       ...           ...
# 323  Your website is super glitchy. It won't let me...  negative             9
# 324  Your website keeps crashing and forgetting eve...  negative           151
# 325   Your website keeps crashing on mobile. It sucks.  negative            61
# 326  Your website's check out system bugs when I us...   neutral             0
# 327                                                NaN   neutral             0
#
# [328 rows x 10 columns]

# %%
data.groupby(['Escalated', 'Sentiment']).mean()[['Process Time']]
# Out:
#                      Process Time
# Escalated Sentiment
# 0         mixed        -17.647059
#           negative       1.603306
#           neutral       11.252174
#           positive       5.828571
# 1         mixed         48.000000
#           negative      20.095238
#           neutral        1.466667
#           positive    -141.500000

# %%
df1 = data[(data['Process Time'] >= 0) & (data['Escalated'] == 1) & (data['Theme'] == 'price')]

# %%
data.to_csv("data_with_sentiment.csv", index=False)
